# %%
from sqlalchemy import create_engine
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker, Session


class SQLAlchemy:
    def __init__(self):
        self._engine = None
        self._session = None

    def init_app(self):
        database_url = 'mysql+pymysql://{}:{}@service-staging-v2-cluster.cluster-cogfzn9i6pkm.ap-northeast-2.rds.amazonaws.com:3306/service1_quicket?charset=utf8'.format(DB_USER, DB_PASSWORD)

        self._engine = create_engine(database_url)
        self._session = sessionmaker(autocommit=False, autoflush=False, bind=self._engine)

    def get_db(self):
        return self._session()

    @property
    def session(self):
        return self.get_db()

    @property
    def engine(self):
        return self._engine

# %%
import datetime
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Boolean, Column, ForeignKey, Integer, String, DateTime


Base = declarative_base()


class BrandT(Base):
    __tablename__ = "brand"

    id = Column(Integer, primary_key=True, index=True)
    name_kor = Column(String, unique=True, index=True)
    name_eng = Column(String, unique=True)
    image_url = Column(String)
    is_active = Column(Integer, default=1)
    used_for_rec = Column(Integer, default=1)
    used_for_follow = Column(Integer, default=1)
    created_at = Column(DateTime, default=datetime.datetime.utcnow)
    modified_at = Column(DateTime, default=datetime.datetime.utcnow)

# %%
mysql = SQLAlchemy()
mysql.init_app()
Base.metadata.create_all(bind=mysql.engine)

# %%
mysql.engine
# Out:
# Engine(mysql+pymysql://dev_emily_park:***@service-staging-v2-cluster.cluster-cogfzn9i6pkm.ap-northeast-2.rds.amazonaws.com:3306/service1_quicket?charset=utf8)

# %%
mysql.session

# %%
def get_active_brands(db: Session):
    return db.query(BrandT).filter(BrandT.is_active == 1).all()

# %%
get_active_brands(mysql.session)

# %%
sql = SQLAlchemy()

# %%
sql.engine
