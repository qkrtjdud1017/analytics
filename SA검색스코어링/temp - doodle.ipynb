# %%
'https://vpc-bun-search-test-e2kx5xade7rrofx7rhqm2seanm.ap-northeast-2.es.amazonaws.com'

# %%
from elasticsearch import Elasticsearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import boto3

# %%
host = 'vpc-bun-search-test-e2kx5xade7rrofx7rhqm2seanm.ap-northeast-2.es.amazonaws.com' # For example, my-test-domain.us-east-1.es.amazonaws.com
region = 'ap-northeast-2' # e.g. us-west-1

service = 'es'
credentials = boto3.Session().get_credentials()
awsauth = AWS4Auth('AKIARPFWUZNYC72RPCAR', '4pE5GepYeFExKXGmYHnKEW3gTbVoNyNWuqGTaZWy', region, service, session_token=credentials.token)

es = Elasticsearch(
    hosts = [{'host': host, 'port': 443}],
    http_auth = awsauth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

# %%
es
# Out:
# <Elasticsearch([{'host': 'vpc-bun-search-test-e2kx5xade7rrofx7rhqm2seanm.ap-northeast-2.es.amazonaws.com', 'port': 443}])>

# %%
query = {
    "size": 5,
    "query": {
        "match": {
            "name": "아이폰"
        }
    }
}
es.search(index='product-active-v1', body=query)
# Out:
# {'took': 2749,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 7.2369237,
#   'hits': [{'_index': 'product-active-v1',
#     '_type': '_doc',
#     '_id': '121002357',
#     '_score': 7.2369237,
#     '_source': {'id': 121002357,
#      'name': '아이폰 아이폰x',
#      'price': 400000,
#      'status': 'SELLING',
#      'description': '상태 양호 구요 깨진곳 없어요 빨리구매시 깍이드림',
#      'imageUrl': 'https://media.bunjang.co.kr/product/121002357_{cnt}_1585677467_w{res}.jpg',
#      'quantity': 1,
#      'user': {'uid': 8922390, 'type': 'NORMAL'},
#      'properties': {'exchange': False,
#       'contact': False,
#       'freeShipping': False,
#       'adult': False,
#       'used': 'USED_NORMAL',
#       'display': 'COUNTRY_AND_NEIGHBORHOOD'},
#      'keywords': ['아이폰x', '아이폰'],
#      'createdAt': '2020-03-31T08:57:44.665',
#      'modifiedAt': '2020-03-31T08:57:47.148',
# ...

# %%
from datetime import datetime, timedelta

# now = datetime.now()
# 2019-10-24T21:40:14.11434
# current_time = now.strftime("%Y-%m-%dT%H:%M:%S")
time = datetime.today() - timedelta(days=2)
# Out:
# datetime.datetime

# %%
str(time)[:10] + 'T' + str(time)[11:]
# Out:
# '2020-06-27T15:06:41.562325'

# %%
datetime.now().strftime("%Y%m%d%H%M%S")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-58ed2f0bcce1> in <module>
# ----> 1 datetime.now().strftime("%Y%m%d%H%M%S")
#
# AttributeError: module 'datetime' has no attribute 'now'

# %%
import requests
from datetime import datetime

parameters = {"q": "샤넬",
             "order": "date", 
             "page": 0,
             "request_id": datetime.now().strftime("%Y%m%d%H%M%S"),
             "stat_uid": 5397308,
             "stat_device": "w",
             "n": 0,
             "stat_category_required": 1,
             "req_ref": "search",
             "version": 4}
# Make a get request with the parameters.
response = requests.get("https://api.bunjang.co.kr/api/1/find_v2.json", params=parameters)

# %%
categories = response.json()['categories'][0]
categories
# Out:
# {'id': '400',
#  'count': 96949,
#  'title': '패션잡화',
#  'order': 2000,
#  'icon_url': 'https://dbgl6r3fnusyg.cloudfront.net/categories_nov_2016/img_category_bag.png',
#  'categories': [{'id': '400010',
#    'count': 43347,
#    'title': '여성가방',
#    'order': 10000,
#    'categories': [{'id': '400010100',
#      'count': 18777,
#      'title': '숄더백',
#      'order': 1000},
#     {'id': '400010200', 'count': 9151, 'title': '크로스백', 'order': 2000},
#     {'id': '400010300', 'count': 4332, 'title': '클러치백', 'order': 3000},
#     {'id': '400010400', 'count': 3484, 'title': '토트백', 'order': 4000},
#     {'id': '400010999', 'count': 3098, 'title': '기타(여성가방)', 'order': 9999},
#     {'id': '400010700', 'count': 1780, 'title': '미니백', 'order': 7000},
#     {'id': '400010500', 'count': 1594, 'title': '백팩', 'order': 5000},
#     {'id': '400010600', 'count': 915, 'title': '파우치', 'order': 6000}]},
#   {'id': '400081',
#    'count': 13863,
#    'title': '주얼리/액세서리',
#    'order': 100000,
# ...

# %%
categories = response.json()['categories'][0]
category_level1 = categories['id']
if categories['categories'][0]:
    category_level2 = categories['categories'][0]['id'][3:]
    if categories['categories'][0]['categories'][0]:
        category_level3 = categories['categories'][0]['categories'][0]['id'][6:]

# %%
print(category_level1)
print(category_level2)
print(category_level3)
# Out:
# 400
# 010
# 100

# %%
datetime.today() - timedelta(days=3)
# Out:
# datetime.datetime(2020, 7, 3, 11, 47, 4, 506552)

# %%
str(datetime.today())
# Out:
# '2020-07-06 11:47:16.278800'
